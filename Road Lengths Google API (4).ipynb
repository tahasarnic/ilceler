# %%
#We have to download the libraries below in order to complete the analysis

# %%
import scrapy
from scrapy import Selector
from scrapy.http import Response
import requests
import re
import pandas as pd
import googlemaps
import folium
import geopandas
import descartes
import matplotlib.pyplot as plt
import mapclassify

# %%
#For the populations in towns below url is web scraped and the obtained populations are compared with the TurkStat data.
#The population data in TurkStat and in below website is the same.

# %%
#Web scraping for the towns and populations

# %%
html = requests.get('https://www.trakyanet.com/istatistikler/nufus/nufus-siralamalari/turkiye-ilce-nufuslari.html').content

# %%
sel = Selector(text=html)

# %%
nüfus = []

# %%
for num in sel.css("tbody").xpath("//td[4]").extract():
    nüfus.append(re.findall('\d+.\d+', num)[0])

# %%
html = requests.get('https://www.trakyanet.com/istatistikler/nufus/nufus-siralamalari/turkiye-ilce-nufuslari.html?start=1').content

# %%
sel = Selector(text=html)

# %%
for num in sel.css("tbody").xpath("//td[4]").extract():
    nüfus.append(re.findall('\d+.\d+', num)[0])

# %%
nüfus=pd.Series(nüfus, name='nüfus')

# %%
nüfus=nüfus.astype('float')

# %%
html = requests.get('https://www.trakyanet.com/istatistikler/nufus/nufus-siralamalari/turkiye-ilce-nufuslari.html').content

# %%
sel = Selector(text=html)

# %%
ilçeler=sel.css("tbody").xpath("//td[2]/text()").extract()

# %%
html = requests.get('https://www.trakyanet.com/istatistikler/nufus/nufus-siralamalari/turkiye-ilce-nufuslari.html?start=1').content

# %%
sel = Selector(text=html)

# %%
for ilçe in sel.css("tbody").xpath("//td[2]/text()").extract():
    ilçeler.append(ilçe)

# %%
#End of webscraping

# %%
#Creating a Pandas dataframe with the obtained population and town name data.

# %%
ilçe = pd.DataFrame(nüfus)

# %%
ilçe['ilçeler'] = ilçeler

# %%
ilçe.set_index('ilçeler',inplace=True)

# %%
ilçe=ilçe*1000

# %%
html = requests.get('https://www.trakyanet.com/istatistikler/nufus/nufus-siralamalari/turkiye-ilce-nufuslari.html').content

# %%
sel = Selector(text=html)

# %%
iller=sel.css("tbody").xpath("//td[3]/text()").extract()

# %%
html = requests.get('https://www.trakyanet.com/istatistikler/nufus/nufus-siralamalari/turkiye-ilce-nufuslari.html?start=1').content

# %%
sel = Selector(text=html)

# %%
for il in sel.css("tbody").xpath("//td[3]/text()").extract():
    iller.append(il)

# %%
ilçe['il'] = iller

# %%
ilçe=ilçe.reset_index()

# %%
ilçe['il_ilçe']='Turkey'+' '+','+ilçe['il'] + ',' + ' '+ ilçe['ilçeler']

# %%
#The created dataframe is like below.

# %%
ilçe
# Out:
#             ilçeler     nüfus              il  \
# 0           Çankaya  920890.0          Ankara
# 1          Keçiören  909787.0          Ankara
# 2          Şahinbey  906043.0       Gaziantep
# 3          Esenyurt  891120.0        İstanbul
# 4         Osmangazi  862516.0           Bursa
# 5            Seyhan  793480.0           Adana
# 6        Şehitkamil  774179.0       Gaziantep
# 7      Küçükçekmece  770317.0        İstanbul
# 8          Bağcılar  734369.0        İstanbul
# 9            Pendik  693599.0        İstanbul
# 10         Ümraniye  690193.0        İstanbul
# 11      Yenimahalle  663580.0          Ankara
# 12         Yıldırım  653004.0           Bursa
# 13         Selçuklu  648850.0           Konya
# 14            Mamak  647252.0          Ankara
# 15     Bahçelievler  594053.0        İstanbul
# 16        Etimesgut  570727.0          Ankara
# 17        Melikgazi  555671.0         Kayseri
# 18            Kepez  531619.0         Antalya
# 19          Üsküdar  529145.0        İstanbul
# 20       Sultangazi  523765.0        İstanbul
# 21           Sincan  518893.0          Ankara
# 22             Buca  499325.0           İzmir
# 23          Maltepe  497034.0        İstanbul
# 24        Muratpaşa  495688.0         Antalya
# 25    Gaziosmanpaşa  487046.0        İstanbul
# 26       Karabağlar  479986.0           İzmir
# 27           Kartal  461155.0        İstanbul
# 28          Kadıköy  458638.0        İstanbul
# 29           Merkez  447106.0          Batman
# ..              ...       ...             ...
# 943          Hanönü    4156.0       Kastamonu
# 944        Seydiler    4143.0       Kastamonu
# 945        Hamamözü    3955.0          Amasya
# 946      Karakeçili    3810.0       Kırıkkale
# 947         Pülümür    3760.0         Tunceli
# 948        Başyayla    3717.0         Karaman
# 949          İbradı    3618.0         Antalya
# 950           Evren    3606.0          Ankara
# 951        Nazımiye    3599.0         Tunceli
# 952     Pehlivanköy    3565.0      Kırklareli
# 953        Doğanşar    3401.0           Sivas
# 954       Mihalgazi    3373.0       Eskişehir
# 955           Kemer    3281.0          Burdur
# 956       Kıbrıscık    3220.0            Bolu
# 957            Ağlı    3196.0       Kastamonu
# 958          Çelebi    3024.0       Kırıkkale
# 959        Bozcaada    3023.0       Çanakkale
# 960      Dumlupınar    2999.0         Kütahya
# 961         İnhisar    2981.0         Bilecik
# 962       Yenipazar    2965.0         Bilecik
# 963          Yedisu    2877.0          Bingöl
# 964          Hemşin    2817.0            Rize
# 965            Ağın    2776.0          Elazığ
# 966       Kızılören    2463.0  Afyonkarahisar
# 967       Otlukbeli    2437.0        Erzincan
# 968          Kofçaz    2368.0      Kırklareli
# 969  Yenişarbademli    2300.0         Isparta
# 970             Han    2272.0       Eskişehir
# 971       Yayladere    2139.0          Bingöl
# 972       Yalıhüyük    1785.0           Konya
#
#                                il_ilçe
# 0              Turkey ,Ankara, Çankaya
# 1             Turkey ,Ankara, Keçiören
# 2          Turkey ,Gaziantep, Şahinbey
# 3           Turkey ,İstanbul, Esenyurt
# 4             Turkey ,Bursa, Osmangazi
# 5                Turkey ,Adana, Seyhan
# 6        Turkey ,Gaziantep, Şehitkamil
# 7       Turkey ,İstanbul, Küçükçekmece
# 8           Turkey ,İstanbul, Bağcılar
# 9             Turkey ,İstanbul, Pendik
# 10          Turkey ,İstanbul, Ümraniye
# 11         Turkey ,Ankara, Yenimahalle
# 12             Turkey ,Bursa, Yıldırım
# 13             Turkey ,Konya, Selçuklu
# 14               Turkey ,Ankara, Mamak
# 15      Turkey ,İstanbul, Bahçelievler
# 16           Turkey ,Ankara, Etimesgut
# 17          Turkey ,Kayseri, Melikgazi
# 18              Turkey ,Antalya, Kepez
# 19           Turkey ,İstanbul, Üsküdar
# 20        Turkey ,İstanbul, Sultangazi
# 21              Turkey ,Ankara, Sincan
# 22                 Turkey ,İzmir, Buca
# 23           Turkey ,İstanbul, Maltepe
# 24          Turkey ,Antalya, Muratpaşa
# 25     Turkey ,İstanbul, Gaziosmanpaşa
# 26           Turkey ,İzmir, Karabağlar
# 27            Turkey ,İstanbul, Kartal
# 28           Turkey ,İstanbul, Kadıköy
# 29              Turkey ,Batman, Merkez
# ..                                 ...
# 943          Turkey ,Kastamonu, Hanönü
# 944        Turkey ,Kastamonu, Seydiler
# 945           Turkey ,Amasya, Hamamözü
# 946      Turkey ,Kırıkkale, Karakeçili
# 947           Turkey ,Tunceli, Pülümür
# 948          Turkey ,Karaman, Başyayla
# 949            Turkey ,Antalya, İbradı
# 950              Turkey ,Ankara, Evren
# 951          Turkey ,Tunceli, Nazımiye
# 952    Turkey ,Kırklareli, Pehlivanköy
# 953            Turkey ,Sivas, Doğanşar
# 954       Turkey ,Eskişehir, Mihalgazi
# 955              Turkey ,Burdur, Kemer
# 956            Turkey ,Bolu, Kıbrıscık
# 957            Turkey ,Kastamonu, Ağlı
# 958          Turkey ,Kırıkkale, Çelebi
# 959        Turkey ,Çanakkale, Bozcaada
# 960        Turkey ,Kütahya, Dumlupınar
# 961           Turkey ,Bilecik, İnhisar
# 962         Turkey ,Bilecik, Yenipazar
# 963             Turkey ,Bingöl, Yedisu
# 964               Turkey ,Rize, Hemşin
# 965               Turkey ,Elazığ, Ağın
# 966  Turkey ,Afyonkarahisar, Kızılören
# 967        Turkey ,Erzincan, Otlukbeli
# 968         Turkey ,Kırklareli, Kofçaz
# 969    Turkey ,Isparta, Yenişarbademli
# 970             Turkey ,Eskişehir, Han
# 971          Turkey ,Bingöl, Yayladere
# 972           Turkey ,Konya, Yalıhüyük
#
# [973 rows x 4 columns]

# %%
#Getting the API key for the location and road distance data from google maps

# %%
api_key  = 'AIzaSyBjfkKq5CNPmRJ113x-CqDeQ5-PCCVAf4s'

# %%
gmaps = googlemaps.Client(key=api_key)

# %%
#Defining functions for getting the northeast and southwest longitudes and latitudes of the towns.

# %%
def get_northeast(location):
    return gmaps.geocode(location)[0]['geometry']['viewport']['northeast']

# %%
def get_southwest(location):
    return gmaps.geocode(location)[0]['geometry']['viewport']['southwest']

# %%
ilçe['northeast'] = ilçe['il_ilçe'].apply(get_northeast)

# %%
ilçe['southwest'] = ilçe['il_ilçe'].apply(get_southwest)

# %%
#With the help of northeast and southwest latitude and longituted information we can use directions api from google maps
#to calculate the road lengths from northeast to southwest with all possible road alternatives.

# %%
roads=[]

# %%
for i in range(0,973):
    roads.append(gmaps.directions(ilçe.iloc[i,4], ilçe.iloc[i,5],alternatives=True))

# %%
ilçe['roads']=roads

# %%
liste=list()
sonuç=0
i=0
while i<len(ilçe):
    if ilçe.iloc[i,6]==[]:
        liste.append(sonuç)
        i+=1
    else:      
        for items in ilçe['roads'][i][0]['legs'][0]['steps']:
            if '<wbr/>' in items['html_instructions']:
                sonuç=sonuç+(items['distance']['value'])
        liste.append(sonuç)
        sonuç=0
        i+=1

# %%
ilçe['toplam_yol'] = liste

# %%
#With the above code total "divided roads/highways" lengths are obtained. With obtained json file from directions api. We can
#access to road names such as "D-200", "O-20" etc. with the '<wbr/>' html object. Then we can extract the road lengths where the
#html object <wbr/> is present in 'html_instructions'.

# %%
ilçe
# Out:
#             ilçeler     nüfus              il  \
# 0           Çankaya  920890.0          Ankara
# 1          Keçiören  909787.0          Ankara
# 2          Şahinbey  906043.0       Gaziantep
# 3          Esenyurt  891120.0        İstanbul
# 4         Osmangazi  862516.0           Bursa
# 5            Seyhan  793480.0           Adana
# 6        Şehitkamil  774179.0       Gaziantep
# 7      Küçükçekmece  770317.0        İstanbul
# 8          Bağcılar  734369.0        İstanbul
# 9            Pendik  693599.0        İstanbul
# 10         Ümraniye  690193.0        İstanbul
# 11      Yenimahalle  663580.0          Ankara
# 12         Yıldırım  653004.0           Bursa
# 13         Selçuklu  648850.0           Konya
# 14            Mamak  647252.0          Ankara
# 15     Bahçelievler  594053.0        İstanbul
# 16        Etimesgut  570727.0          Ankara
# 17        Melikgazi  555671.0         Kayseri
# 18            Kepez  531619.0         Antalya
# 19          Üsküdar  529145.0        İstanbul
# 20       Sultangazi  523765.0        İstanbul
# 21           Sincan  518893.0          Ankara
# 22             Buca  499325.0           İzmir
# 23          Maltepe  497034.0        İstanbul
# 24        Muratpaşa  495688.0         Antalya
# 25    Gaziosmanpaşa  487046.0        İstanbul
# 26       Karabağlar  479986.0           İzmir
# 27           Kartal  461155.0        İstanbul
# 28          Kadıköy  458638.0        İstanbul
# 29           Merkez  447106.0          Batman
# ..              ...       ...             ...
# 943          Hanönü    4156.0       Kastamonu
# 944        Seydiler    4143.0       Kastamonu
# 945        Hamamözü    3955.0          Amasya
# 946      Karakeçili    3810.0       Kırıkkale
# 947         Pülümür    3760.0         Tunceli
# 948        Başyayla    3717.0         Karaman
# 949          İbradı    3618.0         Antalya
# 950           Evren    3606.0          Ankara
# 951        Nazımiye    3599.0         Tunceli
# 952     Pehlivanköy    3565.0      Kırklareli
# 953        Doğanşar    3401.0           Sivas
# 954       Mihalgazi    3373.0       Eskişehir
# 955           Kemer    3281.0          Burdur
# 956       Kıbrıscık    3220.0            Bolu
# 957            Ağlı    3196.0       Kastamonu
# 958          Çelebi    3024.0       Kırıkkale
# 959        Bozcaada    3023.0       Çanakkale
# 960      Dumlupınar    2999.0         Kütahya
# 961         İnhisar    2981.0         Bilecik
# 962       Yenipazar    2965.0         Bilecik
# 963          Yedisu    2877.0          Bingöl
# 964          Hemşin    2817.0            Rize
# 965            Ağın    2776.0          Elazığ
# 966       Kızılören    2463.0  Afyonkarahisar
# 967       Otlukbeli    2437.0        Erzincan
# 968          Kofçaz    2368.0      Kırklareli
# 969  Yenişarbademli    2300.0         Isparta
# 970             Han    2272.0       Eskişehir
# 971       Yayladere    2139.0          Bingöl
# 972       Yalıhüyük    1785.0           Konya
#
#                                il_ilçe  \
# 0              Turkey ,Ankara, Çankaya
# 1             Turkey ,Ankara, Keçiören
# 2          Turkey ,Gaziantep, Şahinbey
# 3           Turkey ,İstanbul, Esenyurt
# 4             Turkey ,Bursa, Osmangazi
# 5                Turkey ,Adana, Seyhan
# 6        Turkey ,Gaziantep, Şehitkamil
# 7       Turkey ,İstanbul, Küçükçekmece
# 8           Turkey ,İstanbul, Bağcılar
# 9             Turkey ,İstanbul, Pendik
# 10          Turkey ,İstanbul, Ümraniye
# 11         Turkey ,Ankara, Yenimahalle
# 12             Turkey ,Bursa, Yıldırım
# 13             Turkey ,Konya, Selçuklu
# 14               Turkey ,Ankara, Mamak
# 15      Turkey ,İstanbul, Bahçelievler
# 16           Turkey ,Ankara, Etimesgut
# 17          Turkey ,Kayseri, Melikgazi
# 18              Turkey ,Antalya, Kepez
# 19           Turkey ,İstanbul, Üsküdar
# 20        Turkey ,İstanbul, Sultangazi
# 21              Turkey ,Ankara, Sincan
# 22                 Turkey ,İzmir, Buca
# 23           Turkey ,İstanbul, Maltepe
# 24          Turkey ,Antalya, Muratpaşa
# 25     Turkey ,İstanbul, Gaziosmanpaşa
# 26           Turkey ,İzmir, Karabağlar
# 27            Turkey ,İstanbul, Kartal
# 28           Turkey ,İstanbul, Kadıköy
# 29              Turkey ,Batman, Merkez
# ..                                 ...
# 943          Turkey ,Kastamonu, Hanönü
# 944        Turkey ,Kastamonu, Seydiler
# 945           Turkey ,Amasya, Hamamözü
# 946      Turkey ,Kırıkkale, Karakeçili
# 947           Turkey ,Tunceli, Pülümür
# 948          Turkey ,Karaman, Başyayla
# 949            Turkey ,Antalya, İbradı
# 950              Turkey ,Ankara, Evren
# 951          Turkey ,Tunceli, Nazımiye
# 952    Turkey ,Kırklareli, Pehlivanköy
# 953            Turkey ,Sivas, Doğanşar
# 954       Turkey ,Eskişehir, Mihalgazi
# 955              Turkey ,Burdur, Kemer
# 956            Turkey ,Bolu, Kıbrıscık
# 957            Turkey ,Kastamonu, Ağlı
# 958          Turkey ,Kırıkkale, Çelebi
# 959        Turkey ,Çanakkale, Bozcaada
# 960        Turkey ,Kütahya, Dumlupınar
# 961           Turkey ,Bilecik, İnhisar
# 962         Turkey ,Bilecik, Yenipazar
# 963             Turkey ,Bingöl, Yedisu
# 964               Turkey ,Rize, Hemşin
# 965               Turkey ,Elazığ, Ağın
# 966  Turkey ,Afyonkarahisar, Kızılören
# 967        Turkey ,Erzincan, Otlukbeli
# 968         Turkey ,Kırklareli, Kofçaz
# 969    Turkey ,Isparta, Yenişarbademli
# 970             Turkey ,Eskişehir, Han
# 971          Turkey ,Bingöl, Yayladere
# 972           Turkey ,Konya, Yalıhüyük
#
#                                          northeast  \
# 0              {'lat': 39.93684, 'lng': 33.139675}
# 1            {'lat': 40.215276, 'lng': 32.9002911}
# 2             {'lat': 37.137932, 'lng': 37.517194}
# 3             {'lat': 41.100767, 'lng': 28.701926}
# 4             {'lat': 40.3447159, 'lng': 29.26984}
# 5             {'lat': 37.065693, 'lng': 35.472058}
# 6            {'lat': 37.108291, 'lng': 37.4567749}
# 7            {'lat': 41.064086, 'lng': 28.8116701}
# 8            {'lat': 41.072214, 'lng': 28.8726901}
# 9              {'lat': 41.036047, 'lng': 29.50651}
# 10           {'lat': 41.0655449, 'lng': 29.194812}
# 11    {'lat': 40.104982, 'lng': 32.84711910000001}
# 12            {'lat': 40.254025, 'lng': 29.210268}
# 13    {'lat': 38.33755590000001, 'lng': 33.021234}
# 14    {'lat': 40.021705, 'lng': 33.16750090000001}
# 15          {'lat': 41.0059208, 'lng': 28.8665634}
# 16          {'lat': 40.0056811, 'lng': 32.7991839}
# 17             {'lat': 38.8248, 'lng': 35.6276751}
# 18    {'lat': 37.169391, 'lng': 30.80611309999999}
# 19            {'lat': 41.077997, 'lng': 29.091789}
# 20              {'lat': 41.159735, 'lng': 28.9226}
# 21    {'lat': 40.158816, 'lng': 32.60545690000001}
# 22          {'lat': 38.4090599, 'lng': 27.3679861}
# 23           {'lat': 40.981197, 'lng': 29.2162771}
# 24   {'lat': 36.93086090000001, 'lng': 30.8673191}
# 25            {'lat': 41.096245, 'lng': 28.939144}
# 26           {'lat': 38.406102, 'lng': 27.1424431}
# 27          {'lat': 40.9630649, 'lng': 29.2551991}
# 28            {'lat': 41.012268, 'lng': 29.111257}
# 29    {'lat': 38.085748, 'lng': 41.43477800000001}
# ..                                             ...
# 943   {'lat': 41.62974000000001, 'lng': 34.474189}
# 944          {'lat': 41.622606, 'lng': 33.7298611}
# 945         {'lat': 40.7894098, 'lng': 35.0307159}
# 946            {'lat': 39.604425, 'lng': 33.39355}
# 947           {'lat': 39.491542, 'lng': 39.902927}
# 948         {'lat': 36.7551561, 'lng': 32.6932921}
# 949           {'lat': 37.10024, 'lng': 31.6042251}
# 950           {'lat': 39.034502, 'lng': 33.816493}
# 951           {'lat': 39.183319, 'lng': 39.833056}
# 952           {'lat': 41.353793, 'lng': 26.932779}
# 953          {'lat': 40.217803, 'lng': 37.5427309}
# 954          {'lat': 40.030412, 'lng': 30.5829319}
# 955           {'lat': 37.361182, 'lng': 30.067797}
# 956         {'lat': 40.4323137, 'lng': 31.9701964}
# 957         {'lat': 41.6920901, 'lng': 33.5560681}
# 958          {'lat': 39.4664379, 'lng': 33.530505}
# 959           {'lat': 39.838029, 'lng': 26.074738}
# 960         {'lat': 38.8564731, 'lng': 29.9857369}
# 961           {'lat': 40.056047, 'lng': 30.388768}
# 962         {'lat': 40.2922221, 'lng': 30.6639579}
# 963  {'lat': 39.4368309, 'lng': 40.54919599999999}
# 964           {'lat': 41.051075, 'lng': 40.903807}
# 965           {'lat': 38.949879, 'lng': 38.719541}
# 966          {'lat': 38.2622279, 'lng': 30.156435}
# 967   {'lat': 39.97799699999999, 'lng': 40.032115}
# 968          {'lat': 41.949467, 'lng': 27.1622309}
# 969          {'lat': 37.715595, 'lng': 31.3981109}
# 970          {'lat': 39.3176061, 'lng': 30.926187}
# 971   {'lat': 39.2294829302915, 'lng': 40.0722151}
# 972          {'lat': 37.3032391, 'lng': 32.105216}
#
#                                          southwest  \
# 0            {'lat': 39.6581571, 'lng': 32.625768}
# 1           {'lat': 39.9577741, 'lng': 32.7403329}
# 2            {'lat': 36.727019, 'lng': 36.9990681}
# 3            {'lat': 40.998827, 'lng': 28.6205251}
# 4     {'lat': 39.98636399999999, 'lng': 28.919984}
# 5             {'lat': 36.929137, 'lng': 35.104076}
# 6            {'lat': 37.0092519, 'lng': 37.303499}
# 7            {'lat': 40.977276, 'lng': 28.7390229}
# 8              {'lat': 41.01752, 'lng': 28.807967}
# 9             {'lat': 40.853817, 'lng': 29.215418}
# 10           {'lat': 40.9889649, 'lng': 29.080289}
# 11            {'lat': 39.91101, 'lng': 32.5632019}
# 12            {'lat': 40.118734, 'lng': 29.061172}
# 13            {'lat': 37.870219, 'lng': 32.060442}
# 14           {'lat': 39.788449, 'lng': 32.8759609}
# 15          {'lat': 40.9890781, 'lng': 28.8345486}
# 16           {'lat': 39.723311, 'lng': 32.4808391}
# 17           {'lat': 38.622002, 'lng': 35.3126991}
# 18           {'lat': 36.893774, 'lng': 30.5900381}
# 19               {'lat': 40.9925, 'lng': 29.00367}
# 20           {'lat': 41.081541, 'lng': 28.8244941}
# 21            {'lat': 39.618199, 'lng': 32.234407}
# 22           {'lat': 38.2703479, 'lng': 27.135691}
# 23            {'lat': 40.9066371, 'lng': 29.09481}
# 24           {'lat': 36.845296, 'lng': 30.6583491}
# 25            {'lat': 41.051592, 'lng': 28.874389}
# 26   {'lat': 38.28773090000001, 'lng': 26.9377679}
# 27           {'lat': 40.878148, 'lng': 29.1382889}
# 28    {'lat': 40.949998, 'lng': 29.01484899999999}
# 29   {'lat': 37.7114829, 'lng': 40.99266009999999}
# ..                                             ...
# 943  {'lat': 41.62329099999999, 'lng': 34.4517009}
# 944           {'lat': 41.61463, 'lng': 33.7122971}
# 945           {'lat': 40.77973, 'lng': 35.0166871}
# 946          {'lat': 39.5844271, 'lng': 33.370025}
# 947  {'lat': 39.48009589999999, 'lng': 39.8893269}
# 948           {'lat': 36.750924, 'lng': 32.676073}
# 949          {'lat': 37.090659, 'lng': 31.5924851}
# 950   {'lat': 39.01186089999999, 'lng': 33.796792}
# 951           {'lat': 39.176338, 'lng': 39.824398}
# 952            {'lat': 41.34489, 'lng': 26.909777}
# 953  {'lat': 40.21066099999999, 'lng': 37.5303671}
# 954         {'lat': 40.0243659, 'lng': 30.5705311}
# 955          {'lat': 37.3465771, 'lng': 30.055196}
# 956         {'lat': 40.4153252, 'lng': 31.9381816}
# 957          {'lat': 41.682406, 'lng': 33.5489119}
# 958  {'lat': 39.45938599999999, 'lng': 33.5189429}
# 959           {'lat': 39.831114, 'lng': 26.060445}
# 960          {'lat': 38.848352, 'lng': 29.9694709}
# 961          {'lat': 40.047325, 'lng': 30.3822809}
# 962          {'lat': 40.1125909, 'lng': 30.370344}
# 963          {'lat': 39.431809, 'lng': 40.5410389}
# 964         {'lat': 41.0430401, 'lng': 40.8944249}
# 965            {'lat': 38.94221, 'lng': 38.702102}
# 966         {'lat': 38.2531851, 'lng': 30.1430531}
# 967          {'lat': 39.970057, 'lng': 40.0162389}
# 968           {'lat': 41.941229, 'lng': 27.153121}
# 969           {'lat': 37.703128, 'lng': 31.381212}
# 970           {'lat': 39.035789, 'lng': 30.687994}
# 971     {'lat': 39.2267849697085, 'lng': 40.06896}
# 972          {'lat': 37.2809479, 'lng': 32.079743}
#
#                                                  roads  toplam_yol
# 0    [{'bounds': {'northeast': {'lat': 39.9701026, ...       54327
# 1    [{'bounds': {'northeast': {'lat': 40.2151211, ...       18535
# 2    [{'bounds': {'northeast': {'lat': 37.1406367, ...       20353
# 3    [{'bounds': {'northeast': {'lat': 41.102674, '...        3669
# 4    [{'bounds': {'northeast': {'lat': 40.3435149, ...       20237
# 5    [{'bounds': {'northeast': {'lat': 37.0666453, ...       31486
# 6    [{'bounds': {'northeast': {'lat': 37.1078643, ...       19738
# 7    [{'bounds': {'northeast': {'lat': 41.0702103, ...       10595
# 8    [{'bounds': {'northeast': {'lat': 41.0745788, ...         127
# 9    [{'bounds': {'northeast': {'lat': 41.0352623, ...       28973
# 10   [{'bounds': {'northeast': {'lat': 41.0801909, ...       10231
# 11   [{'bounds': {'northeast': {'lat': 40.1182767, ...       39925
# 12   [{'bounds': {'northeast': {'lat': 40.2552727, ...       27324
# 13   [{'bounds': {'northeast': {'lat': 38.3380353, ...       53595
# 14   [{'bounds': {'northeast': {'lat': 40.0194237, ...       44920
# 15   [{'bounds': {'northeast': {'lat': 41.0060507, ...        1007
# 16   [{'bounds': {'northeast': {'lat': 40.0271769, ...       52725
# 17   [{'bounds': {'northeast': {'lat': 38.8247876, ...        3198
# 18   [{'bounds': {'northeast': {'lat': 37.1694469, ...       46815
# 19   [{'bounds': {'northeast': {'lat': 41.0890081, ...       15105
# 20   [{'bounds': {'northeast': {'lat': 41.1614098, ...       16481
# 21   [{'bounds': {'northeast': {'lat': 40.1625991, ...       52324
# 22   [{'bounds': {'northeast': {'lat': 38.4712479, ...       37333
# 23   [{'bounds': {'northeast': {'lat': 40.984884699...       65949
# 24   [{'bounds': {'northeast': {'lat': 36.9480636, ...       21011
# 25   [{'bounds': {'northeast': {'lat': 41.0968161, ...        3593
# 26   [{'bounds': {'northeast': {'lat': 38.4069333, ...       11753
# 27   [{'bounds': {'northeast': {'lat': 40.9978369, ...       26169
# 28   [{'bounds': {'northeast': {'lat': 41.0122554, ...        4960
# 29   [{'bounds': {'northeast': {'lat': 38.0858522, ...       52349
# ..                                                 ...         ...
# 943  [{'bounds': {'northeast': {'lat': 41.6295811, ...        5117
# 944  [{'bounds': {'northeast': {'lat': 41.6251682, ...        1719
# 945  [{'bounds': {'northeast': {'lat': 40.7894371, ...           0
# 946  [{'bounds': {'northeast': {'lat': 39.6021194, ...           0
# 947  [{'bounds': {'northeast': {'lat': 39.4905404, ...           0
# 948  [{'bounds': {'northeast': {'lat': 36.7536037, ...           0
# 949  [{'bounds': {'northeast': {'lat': 37.1003563, ...           0
# 950  [{'bounds': {'northeast': {'lat': 39.0326502, ...           0
# 951  [{'bounds': {'northeast': {'lat': 39.18357, 'l...         421
# 952  [{'bounds': {'northeast': {'lat': 41.3543794, ...           0
# 953  [{'bounds': {'northeast': {'lat': 40.2186752, ...           0
# 954  [{'bounds': {'northeast': {'lat': 40.0303023, ...           0
# 955  [{'bounds': {'northeast': {'lat': 37.3624743, ...           0
# 956  [{'bounds': {'northeast': {'lat': 40.4296879, ...           0
# 957  [{'bounds': {'northeast': {'lat': 41.6913229, ...         380
# 958  [{'bounds': {'northeast': {'lat': 39.4668603, ...           0
# 959  [{'bounds': {'northeast': {'lat': 39.8355459, ...           0
# 960  [{'bounds': {'northeast': {'lat': 38.856664500...           0
# 961  [{'bounds': {'northeast': {'lat': 40.0560498, ...           0
# 962  [{'bounds': {'northeast': {'lat': 40.3044153, ...           0
# 963  [{'bounds': {'northeast': {'lat': 39.4350026, ...           0
# 964  [{'bounds': {'northeast': {'lat': 41.0518315, ...           0
# 965  [{'bounds': {'northeast': {'lat': 38.9470461, ...           0
# 966  [{'bounds': {'northeast': {'lat': 38.2623002, ...           0
# 967  [{'bounds': {'northeast': {'lat': 39.9777274, ...           0
# 968  [{'bounds': {'northeast': {'lat': 41.9495016, ...           0
# 969  [{'bounds': {'northeast': {'lat': 37.7153892, ...           0
# 970  [{'bounds': {'northeast': {'lat': 39.3575429, ...           0
# 971  [{'bounds': {'northeast': {'lat': 39.2291011, ...           0
# 972  [{'bounds': {'northeast': {'lat': 37.3016372, ...        1124
#
# [973 rows x 8 columns]

# %%
#For the below towns google maps api gave no result. So the "divided/highway" road lengths are calculated with the help of
#Google Earth.
#74, 98, 112, 150, 185,  190,  233, 235, 290,299, 423, 533, 787
#mersin toroslar 74 = 7000
#istanbul büyükçekmece 98 = 727
#ordu altınordu 112 = 20000
#erzincan merkez 150 = 53000
#ordu ünye 185 = 10600
#hatay dörtyol 190 = 25000
#izmir menderes 233 = 3700
#şırnak merkez 235 = 57000
#sinop merkez 290 = 36000
#muğla seydikemer 299 = 70000
#van gürpınar 423 = 55000
#tekirdağ marmaraereğlisi 533 = 25000
#kayseri sarız 787 = 35000

# %%
ilçe.iloc[74,7] = 7000
ilçe.iloc[98,7] = 727
ilçe.iloc[112,7] = 20000
ilçe.iloc[150,7] = 53000
ilçe.iloc[185,7] = 10600
ilçe.iloc[190,7] = 25000
ilçe.iloc[233,7] = 3700
ilçe.iloc[235,7] = 57000
ilçe.iloc[290,7] = 36000
ilçe.iloc[299,7] = 70000
ilçe.iloc[423,7] = 55000
ilçe.iloc[533,7] = 25000
ilçe.iloc[787,7] = 35000

# %%
#Below code is for calculating the per capita road lengths of the towns.

# %%
ilçe['kişibaşına_yol'] = ilçe['toplam_yol'] / ilçe['nüfus']

# %%
ilçe
# Out:
#             ilçeler     nüfus              il  \
# 0           Çankaya  920890.0          Ankara
# 1          Keçiören  909787.0          Ankara
# 2          Şahinbey  906043.0       Gaziantep
# 3          Esenyurt  891120.0        İstanbul
# 4         Osmangazi  862516.0           Bursa
# 5            Seyhan  793480.0           Adana
# 6        Şehitkamil  774179.0       Gaziantep
# 7      Küçükçekmece  770317.0        İstanbul
# 8          Bağcılar  734369.0        İstanbul
# 9            Pendik  693599.0        İstanbul
# 10         Ümraniye  690193.0        İstanbul
# 11      Yenimahalle  663580.0          Ankara
# 12         Yıldırım  653004.0           Bursa
# 13         Selçuklu  648850.0           Konya
# 14            Mamak  647252.0          Ankara
# 15     Bahçelievler  594053.0        İstanbul
# 16        Etimesgut  570727.0          Ankara
# 17        Melikgazi  555671.0         Kayseri
# 18            Kepez  531619.0         Antalya
# 19          Üsküdar  529145.0        İstanbul
# 20       Sultangazi  523765.0        İstanbul
# 21           Sincan  518893.0          Ankara
# 22             Buca  499325.0           İzmir
# 23          Maltepe  497034.0        İstanbul
# 24        Muratpaşa  495688.0         Antalya
# 25    Gaziosmanpaşa  487046.0        İstanbul
# 26       Karabağlar  479986.0           İzmir
# 27           Kartal  461155.0        İstanbul
# 28          Kadıköy  458638.0        İstanbul
# 29           Merkez  447106.0          Batman
# ..              ...       ...             ...
# 943          Hanönü    4156.0       Kastamonu
# 944        Seydiler    4143.0       Kastamonu
# 945        Hamamözü    3955.0          Amasya
# 946      Karakeçili    3810.0       Kırıkkale
# 947         Pülümür    3760.0         Tunceli
# 948        Başyayla    3717.0         Karaman
# 949          İbradı    3618.0         Antalya
# 950           Evren    3606.0          Ankara
# 951        Nazımiye    3599.0         Tunceli
# 952     Pehlivanköy    3565.0      Kırklareli
# 953        Doğanşar    3401.0           Sivas
# 954       Mihalgazi    3373.0       Eskişehir
# 955           Kemer    3281.0          Burdur
# 956       Kıbrıscık    3220.0            Bolu
# 957            Ağlı    3196.0       Kastamonu
# 958          Çelebi    3024.0       Kırıkkale
# 959        Bozcaada    3023.0       Çanakkale
# 960      Dumlupınar    2999.0         Kütahya
# 961         İnhisar    2981.0         Bilecik
# 962       Yenipazar    2965.0         Bilecik
# 963          Yedisu    2877.0          Bingöl
# 964          Hemşin    2817.0            Rize
# 965            Ağın    2776.0          Elazığ
# 966       Kızılören    2463.0  Afyonkarahisar
# 967       Otlukbeli    2437.0        Erzincan
# 968          Kofçaz    2368.0      Kırklareli
# 969  Yenişarbademli    2300.0         Isparta
# 970             Han    2272.0       Eskişehir
# 971       Yayladere    2139.0          Bingöl
# 972       Yalıhüyük    1785.0           Konya
#
#                                il_ilçe  \
# 0              Turkey ,Ankara, Çankaya
# 1             Turkey ,Ankara, Keçiören
# 2          Turkey ,Gaziantep, Şahinbey
# 3           Turkey ,İstanbul, Esenyurt
# 4             Turkey ,Bursa, Osmangazi
# 5                Turkey ,Adana, Seyhan
# 6        Turkey ,Gaziantep, Şehitkamil
# 7       Turkey ,İstanbul, Küçükçekmece
# 8           Turkey ,İstanbul, Bağcılar
# 9             Turkey ,İstanbul, Pendik
# 10          Turkey ,İstanbul, Ümraniye
# 11         Turkey ,Ankara, Yenimahalle
# 12             Turkey ,Bursa, Yıldırım
# 13             Turkey ,Konya, Selçuklu
# 14               Turkey ,Ankara, Mamak
# 15      Turkey ,İstanbul, Bahçelievler
# 16           Turkey ,Ankara, Etimesgut
# 17          Turkey ,Kayseri, Melikgazi
# 18              Turkey ,Antalya, Kepez
# 19           Turkey ,İstanbul, Üsküdar
# 20        Turkey ,İstanbul, Sultangazi
# 21              Turkey ,Ankara, Sincan
# 22                 Turkey ,İzmir, Buca
# 23           Turkey ,İstanbul, Maltepe
# 24          Turkey ,Antalya, Muratpaşa
# 25     Turkey ,İstanbul, Gaziosmanpaşa
# 26           Turkey ,İzmir, Karabağlar
# 27            Turkey ,İstanbul, Kartal
# 28           Turkey ,İstanbul, Kadıköy
# 29              Turkey ,Batman, Merkez
# ..                                 ...
# 943          Turkey ,Kastamonu, Hanönü
# 944        Turkey ,Kastamonu, Seydiler
# 945           Turkey ,Amasya, Hamamözü
# 946      Turkey ,Kırıkkale, Karakeçili
# 947           Turkey ,Tunceli, Pülümür
# 948          Turkey ,Karaman, Başyayla
# 949            Turkey ,Antalya, İbradı
# 950              Turkey ,Ankara, Evren
# 951          Turkey ,Tunceli, Nazımiye
# 952    Turkey ,Kırklareli, Pehlivanköy
# 953            Turkey ,Sivas, Doğanşar
# 954       Turkey ,Eskişehir, Mihalgazi
# 955              Turkey ,Burdur, Kemer
# 956            Turkey ,Bolu, Kıbrıscık
# 957            Turkey ,Kastamonu, Ağlı
# 958          Turkey ,Kırıkkale, Çelebi
# 959        Turkey ,Çanakkale, Bozcaada
# 960        Turkey ,Kütahya, Dumlupınar
# 961           Turkey ,Bilecik, İnhisar
# 962         Turkey ,Bilecik, Yenipazar
# 963             Turkey ,Bingöl, Yedisu
# 964               Turkey ,Rize, Hemşin
# 965               Turkey ,Elazığ, Ağın
# 966  Turkey ,Afyonkarahisar, Kızılören
# 967        Turkey ,Erzincan, Otlukbeli
# 968         Turkey ,Kırklareli, Kofçaz
# 969    Turkey ,Isparta, Yenişarbademli
# 970             Turkey ,Eskişehir, Han
# 971          Turkey ,Bingöl, Yayladere
# 972           Turkey ,Konya, Yalıhüyük
#
#                                          northeast  \
# 0              {'lat': 39.93684, 'lng': 33.139675}
# 1            {'lat': 40.215276, 'lng': 32.9002911}
# 2             {'lat': 37.137932, 'lng': 37.517194}
# 3             {'lat': 41.100767, 'lng': 28.701926}
# 4             {'lat': 40.3447159, 'lng': 29.26984}
# 5             {'lat': 37.065693, 'lng': 35.472058}
# 6            {'lat': 37.108291, 'lng': 37.4567749}
# 7            {'lat': 41.064086, 'lng': 28.8116701}
# 8            {'lat': 41.072214, 'lng': 28.8726901}
# 9              {'lat': 41.036047, 'lng': 29.50651}
# 10           {'lat': 41.0655449, 'lng': 29.194812}
# 11    {'lat': 40.104982, 'lng': 32.84711910000001}
# 12            {'lat': 40.254025, 'lng': 29.210268}
# 13    {'lat': 38.33755590000001, 'lng': 33.021234}
# 14    {'lat': 40.021705, 'lng': 33.16750090000001}
# 15          {'lat': 41.0059208, 'lng': 28.8665634}
# 16          {'lat': 40.0056811, 'lng': 32.7991839}
# 17             {'lat': 38.8248, 'lng': 35.6276751}
# 18    {'lat': 37.169391, 'lng': 30.80611309999999}
# 19            {'lat': 41.077997, 'lng': 29.091789}
# 20              {'lat': 41.159735, 'lng': 28.9226}
# 21    {'lat': 40.158816, 'lng': 32.60545690000001}
# 22          {'lat': 38.4090599, 'lng': 27.3679861}
# 23           {'lat': 40.981197, 'lng': 29.2162771}
# 24   {'lat': 36.93086090000001, 'lng': 30.8673191}
# 25            {'lat': 41.096245, 'lng': 28.939144}
# 26           {'lat': 38.406102, 'lng': 27.1424431}
# 27          {'lat': 40.9630649, 'lng': 29.2551991}
# 28            {'lat': 41.012268, 'lng': 29.111257}
# 29    {'lat': 38.085748, 'lng': 41.43477800000001}
# ..                                             ...
# 943   {'lat': 41.62974000000001, 'lng': 34.474189}
# 944          {'lat': 41.622606, 'lng': 33.7298611}
# 945         {'lat': 40.7894098, 'lng': 35.0307159}
# 946            {'lat': 39.604425, 'lng': 33.39355}
# 947           {'lat': 39.491542, 'lng': 39.902927}
# 948         {'lat': 36.7551561, 'lng': 32.6932921}
# 949           {'lat': 37.10024, 'lng': 31.6042251}
# 950           {'lat': 39.034502, 'lng': 33.816493}
# 951           {'lat': 39.183319, 'lng': 39.833056}
# 952           {'lat': 41.353793, 'lng': 26.932779}
# 953          {'lat': 40.217803, 'lng': 37.5427309}
# 954          {'lat': 40.030412, 'lng': 30.5829319}
# 955           {'lat': 37.361182, 'lng': 30.067797}
# 956         {'lat': 40.4323137, 'lng': 31.9701964}
# 957         {'lat': 41.6920901, 'lng': 33.5560681}
# 958          {'lat': 39.4664379, 'lng': 33.530505}
# 959           {'lat': 39.838029, 'lng': 26.074738}
# 960         {'lat': 38.8564731, 'lng': 29.9857369}
# 961           {'lat': 40.056047, 'lng': 30.388768}
# 962         {'lat': 40.2922221, 'lng': 30.6639579}
# 963  {'lat': 39.4368309, 'lng': 40.54919599999999}
# 964           {'lat': 41.051075, 'lng': 40.903807}
# 965           {'lat': 38.949879, 'lng': 38.719541}
# 966          {'lat': 38.2622279, 'lng': 30.156435}
# 967   {'lat': 39.97799699999999, 'lng': 40.032115}
# 968          {'lat': 41.949467, 'lng': 27.1622309}
# 969          {'lat': 37.715595, 'lng': 31.3981109}
# 970          {'lat': 39.3176061, 'lng': 30.926187}
# 971   {'lat': 39.2294829302915, 'lng': 40.0722151}
# 972          {'lat': 37.3032391, 'lng': 32.105216}
#
#                                          southwest  \
# 0            {'lat': 39.6581571, 'lng': 32.625768}
# 1           {'lat': 39.9577741, 'lng': 32.7403329}
# 2            {'lat': 36.727019, 'lng': 36.9990681}
# 3            {'lat': 40.998827, 'lng': 28.6205251}
# 4     {'lat': 39.98636399999999, 'lng': 28.919984}
# 5             {'lat': 36.929137, 'lng': 35.104076}
# 6            {'lat': 37.0092519, 'lng': 37.303499}
# 7            {'lat': 40.977276, 'lng': 28.7390229}
# 8              {'lat': 41.01752, 'lng': 28.807967}
# 9             {'lat': 40.853817, 'lng': 29.215418}
# 10           {'lat': 40.9889649, 'lng': 29.080289}
# 11            {'lat': 39.91101, 'lng': 32.5632019}
# 12            {'lat': 40.118734, 'lng': 29.061172}
# 13            {'lat': 37.870219, 'lng': 32.060442}
# 14           {'lat': 39.788449, 'lng': 32.8759609}
# 15          {'lat': 40.9890781, 'lng': 28.8345486}
# 16           {'lat': 39.723311, 'lng': 32.4808391}
# 17           {'lat': 38.622002, 'lng': 35.3126991}
# 18           {'lat': 36.893774, 'lng': 30.5900381}
# 19               {'lat': 40.9925, 'lng': 29.00367}
# 20           {'lat': 41.081541, 'lng': 28.8244941}
# 21            {'lat': 39.618199, 'lng': 32.234407}
# 22           {'lat': 38.2703479, 'lng': 27.135691}
# 23            {'lat': 40.9066371, 'lng': 29.09481}
# 24           {'lat': 36.845296, 'lng': 30.6583491}
# 25            {'lat': 41.051592, 'lng': 28.874389}
# 26   {'lat': 38.28773090000001, 'lng': 26.9377679}
# 27           {'lat': 40.878148, 'lng': 29.1382889}
# 28    {'lat': 40.949998, 'lng': 29.01484899999999}
# 29   {'lat': 37.7114829, 'lng': 40.99266009999999}
# ..                                             ...
# 943  {'lat': 41.62329099999999, 'lng': 34.4517009}
# 944           {'lat': 41.61463, 'lng': 33.7122971}
# 945           {'lat': 40.77973, 'lng': 35.0166871}
# 946          {'lat': 39.5844271, 'lng': 33.370025}
# 947  {'lat': 39.48009589999999, 'lng': 39.8893269}
# 948           {'lat': 36.750924, 'lng': 32.676073}
# 949          {'lat': 37.090659, 'lng': 31.5924851}
# 950   {'lat': 39.01186089999999, 'lng': 33.796792}
# 951           {'lat': 39.176338, 'lng': 39.824398}
# 952            {'lat': 41.34489, 'lng': 26.909777}
# 953  {'lat': 40.21066099999999, 'lng': 37.5303671}
# 954         {'lat': 40.0243659, 'lng': 30.5705311}
# 955          {'lat': 37.3465771, 'lng': 30.055196}
# 956         {'lat': 40.4153252, 'lng': 31.9381816}
# 957          {'lat': 41.682406, 'lng': 33.5489119}
# 958  {'lat': 39.45938599999999, 'lng': 33.5189429}
# 959           {'lat': 39.831114, 'lng': 26.060445}
# 960          {'lat': 38.848352, 'lng': 29.9694709}
# 961          {'lat': 40.047325, 'lng': 30.3822809}
# 962          {'lat': 40.1125909, 'lng': 30.370344}
# 963          {'lat': 39.431809, 'lng': 40.5410389}
# 964         {'lat': 41.0430401, 'lng': 40.8944249}
# 965            {'lat': 38.94221, 'lng': 38.702102}
# 966         {'lat': 38.2531851, 'lng': 30.1430531}
# 967          {'lat': 39.970057, 'lng': 40.0162389}
# 968           {'lat': 41.941229, 'lng': 27.153121}
# 969           {'lat': 37.703128, 'lng': 31.381212}
# 970           {'lat': 39.035789, 'lng': 30.687994}
# 971     {'lat': 39.2267849697085, 'lng': 40.06896}
# 972          {'lat': 37.2809479, 'lng': 32.079743}
#
#                                                  roads  toplam_yol  \
# 0    [{'bounds': {'northeast': {'lat': 39.9701026, ...       54327
# 1    [{'bounds': {'northeast': {'lat': 40.2151211, ...       18535
# 2    [{'bounds': {'northeast': {'lat': 37.1406367, ...       20353
# 3    [{'bounds': {'northeast': {'lat': 41.102674, '...        3669
# 4    [{'bounds': {'northeast': {'lat': 40.3435149, ...       20237
# 5    [{'bounds': {'northeast': {'lat': 37.0666453, ...       31486
# 6    [{'bounds': {'northeast': {'lat': 37.1078643, ...       19738
# 7    [{'bounds': {'northeast': {'lat': 41.0702103, ...       10595
# 8    [{'bounds': {'northeast': {'lat': 41.0745788, ...         127
# 9    [{'bounds': {'northeast': {'lat': 41.0352623, ...       28973
# 10   [{'bounds': {'northeast': {'lat': 41.0801909, ...       10231
# 11   [{'bounds': {'northeast': {'lat': 40.1182767, ...       39925
# 12   [{'bounds': {'northeast': {'lat': 40.2552727, ...       27324
# 13   [{'bounds': {'northeast': {'lat': 38.3380353, ...       53595
# 14   [{'bounds': {'northeast': {'lat': 40.0194237, ...       44920
# 15   [{'bounds': {'northeast': {'lat': 41.0060507, ...        1007
# 16   [{'bounds': {'northeast': {'lat': 40.0271769, ...       52725
# 17   [{'bounds': {'northeast': {'lat': 38.8247876, ...        3198
# 18   [{'bounds': {'northeast': {'lat': 37.1694469, ...       46815
# 19   [{'bounds': {'northeast': {'lat': 41.0890081, ...       15105
# 20   [{'bounds': {'northeast': {'lat': 41.1614098, ...       16481
# 21   [{'bounds': {'northeast': {'lat': 40.1625991, ...       52324
# 22   [{'bounds': {'northeast': {'lat': 38.4712479, ...       37333
# 23   [{'bounds': {'northeast': {'lat': 40.984884699...       65949
# 24   [{'bounds': {'northeast': {'lat': 36.9480636, ...       21011
# 25   [{'bounds': {'northeast': {'lat': 41.0968161, ...        3593
# 26   [{'bounds': {'northeast': {'lat': 38.4069333, ...       11753
# 27   [{'bounds': {'northeast': {'lat': 40.9978369, ...       26169
# 28   [{'bounds': {'northeast': {'lat': 41.0122554, ...        4960
# 29   [{'bounds': {'northeast': {'lat': 38.0858522, ...       52349
# ..                                                 ...         ...
# 943  [{'bounds': {'northeast': {'lat': 41.6295811, ...        5117
# 944  [{'bounds': {'northeast': {'lat': 41.6251682, ...        1719
# 945  [{'bounds': {'northeast': {'lat': 40.7894371, ...           0
# 946  [{'bounds': {'northeast': {'lat': 39.6021194, ...           0
# 947  [{'bounds': {'northeast': {'lat': 39.4905404, ...           0
# 948  [{'bounds': {'northeast': {'lat': 36.7536037, ...           0
# 949  [{'bounds': {'northeast': {'lat': 37.1003563, ...           0
# 950  [{'bounds': {'northeast': {'lat': 39.0326502, ...           0
# 951  [{'bounds': {'northeast': {'lat': 39.18357, 'l...         421
# 952  [{'bounds': {'northeast': {'lat': 41.3543794, ...           0
# 953  [{'bounds': {'northeast': {'lat': 40.2186752, ...           0
# 954  [{'bounds': {'northeast': {'lat': 40.0303023, ...           0
# 955  [{'bounds': {'northeast': {'lat': 37.3624743, ...           0
# 956  [{'bounds': {'northeast': {'lat': 40.4296879, ...           0
# 957  [{'bounds': {'northeast': {'lat': 41.6913229, ...         380
# 958  [{'bounds': {'northeast': {'lat': 39.4668603, ...           0
# 959  [{'bounds': {'northeast': {'lat': 39.8355459, ...           0
# 960  [{'bounds': {'northeast': {'lat': 38.856664500...           0
# 961  [{'bounds': {'northeast': {'lat': 40.0560498, ...           0
# 962  [{'bounds': {'northeast': {'lat': 40.3044153, ...           0
# 963  [{'bounds': {'northeast': {'lat': 39.4350026, ...           0
# 964  [{'bounds': {'northeast': {'lat': 41.0518315, ...           0
# 965  [{'bounds': {'northeast': {'lat': 38.9470461, ...           0
# 966  [{'bounds': {'northeast': {'lat': 38.2623002, ...           0
# 967  [{'bounds': {'northeast': {'lat': 39.9777274, ...           0
# 968  [{'bounds': {'northeast': {'lat': 41.9495016, ...           0
# 969  [{'bounds': {'northeast': {'lat': 37.7153892, ...           0
# 970  [{'bounds': {'northeast': {'lat': 39.3575429, ...           0
# 971  [{'bounds': {'northeast': {'lat': 39.2291011, ...           0
# 972  [{'bounds': {'northeast': {'lat': 37.3016372, ...        1124
#
#      kişibaşına_yol
# 0          0.058994
# 1          0.020373
# 2          0.022464
# 3          0.004117
# 4          0.023463
# 5          0.039681
# 6          0.025495
# 7          0.013754
# 8          0.000173
# 9          0.041772
# 10         0.014823
# 11         0.060166
# 12         0.041844
# 13         0.082600
# 14         0.069401
# 15         0.001695
# 16         0.092382
# 17         0.005755
# 18         0.088061
# 19         0.028546
# 20         0.031466
# 21         0.100838
# 22         0.074767
# 23         0.132685
# 24         0.042388
# 25         0.007377
# 26         0.024486
# 27         0.056747
# 28         0.010815
# 29         0.117084
# ..              ...
# 943        1.231232
# 944        0.414917
# 945        0.000000
# 946        0.000000
# 947        0.000000
# 948        0.000000
# 949        0.000000
# 950        0.000000
# 951        0.116977
# 952        0.000000
# 953        0.000000
# 954        0.000000
# 955        0.000000
# 956        0.000000
# 957        0.118899
# 958        0.000000
# 959        0.000000
# 960        0.000000
# 961        0.000000
# 962        0.000000
# 963        0.000000
# 964        0.000000
# 965        0.000000
# 966        0.000000
# 967        0.000000
# 968        0.000000
# 969        0.000000
# 970        0.000000
# 971        0.000000
# 972        0.629692
#
# [973 rows x 9 columns]

# %%
#For chloropeth heatmapping I wanted to use polygons of the towns. Found a polygon geojson data of towns in Turkey and called
#the data with the help of github. Created polygons dataframe containing geometric data of the towns.

# %%
polygons=geopandas.read_file('https://raw.githubusercontent.com/tahasarnic/ilceler/master/turkiye-ilceler.geojson')

# %%
ilçe.sort_values(by='ilçeler', ascending=True, inplace=True)

# %%
polygons.sort_values(by='name', inplace=True)

# %%
polygons = polygons[['name', 'synonyms', 'geometry', 'tessellate']]

# %%
polygons.loc[12, 'name'] = 'Çerkeş'
polygons.loc[722, 'name'] = 'Çamaş'
polygons.loc[571, 'name'] = 'Yahyalı'
polygons.loc[650, 'name'] = 'Pütürge'
polygons.loc[29, 'name'] = 'Kargı'
polygons.loc[117, 'name'] = 'Kahramankazan'
polygons.loc[880, 'name'] = 'Nazımiye'
polygons.loc[496, 'name'] = 'Andırın'

# %%
ilçe.drop([241, 272],axis=0, inplace=True)

# %%
ilçe.drop(107, axis=0, inplace=True)

# %%
#Below, the town names are changed accordingly to polygons dataset in order to match them correctly.

# %%
ilçe.loc[718, 'ilçeler'] = 'Sabanözü'
ilçe.loc[70, 'ilçeler'] = 'Yeşilyurt (Malatya)'
ilçe.loc[813, 'ilçeler'] = 'Yeşilyurt (Tokat)'
ilçe.loc[742, 'ilçeler'] = 'Yenipazar (Aydın)'
ilçe.loc[962, 'ilçeler'] = 'Yenipazar (Bilecik)'
ilçe.loc[587, 'ilçeler'] = 'Yenice (Karabük)'
ilçe.loc[472, 'ilçeler'] = 'Yenice (Çanakkale)'
ilçe.loc[739, 'ilçeler'] = 'Ulubey (Uşak)'
ilçe.loc[521, 'ilçeler'] = 'Ulubey (Ordu)'
ilçe.loc[866, 'ilçeler'] = 'Süleoğlu'
ilçe.loc[591, 'ilçeler'] = 'Saray (Van)'
ilçe.loc[341, 'ilçeler'] = 'Saray (Tekirdağ)'
ilçe.loc[517, 'ilçeler'] = 'Pınarbaşı (Kayseri)'
ilçe.loc[903, 'ilçeler'] = 'Pınarbaşı (Kastamonu)'
ilçe.loc[712, 'ilçeler'] = 'Pazar (Tokat)'
ilçe.loc[473, 'ilçeler'] = 'Pazar (Rize)'
ilçe.loc[923, 'ilçeler'] = 'Ovacık (Karabük)'
ilçe.loc[869, 'ilçeler'] = 'Ovacık (Tunceli)'
ilçe.loc[465, 'ilçeler'] = 'Ortaköy (Aksaray)'
ilçe.loc[829, 'ilçeler'] = 'Ortaköy (Çorum)'
ilçe.loc[223, 'ilçeler'] = 'Mustafa Kemalpaşa'
ilçe.loc[120, 'ilçeler'] = 'Merkez (Muş)'
ilçe.loc[128, 'ilçeler'] = 'Merkez (Edirne)'
ilçe.loc[95, 'ilçeler'] = 'Merkez (Uşak)'
ilçe.loc[147, 'ilçeler'] = 'Merkez (Bingöl)'
ilçe.loc[88, 'ilçeler'] = 'Merkez (Osmaniye)'
ilçe.loc[114, 'ilçeler'] = 'Merkez (Kırıkkale)'
ilçe.loc[127, 'ilçeler'] = 'Merkez (Çanakkale)'
ilçe.loc[408, 'ilçeler'] = 'Merkez (Tunceli)'
ilçe.loc[104, 'ilçeler'] = 'Merkez (Niğde)'
ilçe.loc[381, 'ilçeler'] = 'Merkez (Ardahan)'
ilçe.loc[429, 'ilçeler'] = 'Merkez (Artvin)'
ilçe.loc[100, 'ilçeler'] = 'Merkez (Düzce)'
ilçe.loc[108, 'ilçeler'] = 'Merkez (Bolu)'
ilçe.loc[150, 'ilçeler'] = 'Merkez (Erzincan)'
ilçe.loc[119, 'ilçeler'] = 'Merkez (Karaman)'
ilçe.loc[181, 'ilçeler'] = 'Merkez (Karabük)'
ilçe.loc[177, 'ilçeler'] = 'Merkez (Giresun)'
ilçe.loc[175, 'ilçeler'] = 'Merkez (Iğdır)'
ilçe.loc[77, 'ilçeler'] = 'Merkez (Çorum)'
ilçe.loc[290, 'ilçeler'] = 'Merkez (Sinop)'
ilçe.loc[169, 'ilçeler'] = 'Merkez (Rize)'
ilçe.loc[273, 'ilçeler'] = 'Merkez (Bitlis)'
ilçe.loc[111, 'ilçeler'] = 'Merkez (Tokat)'
ilçe.loc[91, 'ilçeler'] = 'Merkez (Isparta)'
ilçe.loc[140, 'ilçeler'] = 'Merkez (Siirt)'
ilçe.loc[86, 'ilçeler'] = 'Merkez (Kütahya)'
ilçe.loc[311, 'ilçeler'] = 'Merkez (Gümüşhane)'
ilçe.loc[48, 'ilçeler'] = 'Merkez (Sivas)'
ilçe.loc[162, 'ilçeler'] = 'Merkez (Yalova)'
ilçe.loc[163, 'ilçeler'] = 'Merkez (Nevşehir)'
ilçe.loc[254, 'ilçeler'] = 'Merkez (Bilecik)'
ilçe.loc[255, 'ilçeler'] = 'Merkez (Hakkari)'
ilçe.loc[158, 'ilçeler'] = 'Merkez (Amasya)'
ilçe.loc[159, 'ilçeler'] = 'Merkez (Kastamonu)'
ilçe.loc[227, 'ilçeler'] = 'Merkez (Çankırı)'
ilçe.loc[235, 'ilçeler'] = 'Merkez (Şırnak)'
ilçe.loc[187, 'ilçeler'] = 'Merkez (Zonguldak)'
ilçe.loc[157, 'ilçeler'] = 'Merkez (Ağrı)'
ilçe.loc[210, 'ilçeler'] = 'Merkez (Burdur)'
ilçe.loc[217, 'ilçeler'] = 'Merkez (Yozgat)'
ilçe.loc[221, 'ilçeler'] = 'Merkez (Kırklareli)'
ilçe.loc[152, 'ilçeler'] = 'Merkez (Bartın)'
ilçe.loc[155, 'ilçeler'] = 'Merkez (Kırşehir)'
ilçe.loc[73, 'ilçeler'] = 'Merkez (Afyonkarahisar)'
ilçe.loc[71, 'ilçeler'] = 'Merkez (Adıyaman)'
ilçe.loc[76, 'ilçeler'] = 'Merkez (Aksaray)'
ilçe.loc[205, 'ilçeler'] = 'Merkez (Kars)'
ilçe.loc[37, 'ilçeler'] = 'Merkez (Elazığ)'
ilçe.loc[204, 'ilçeler'] = 'Merkez (Kilis)'
ilçe.loc[29, 'ilçeler'] = 'Merkez (Batman)'
ilçe.loc[281, 'ilçeler'] = 'Merkez (Bayburt)'
ilçe.loc[731, 'ilçeler'] = 'Köprübaşı (Manisa)'
ilçe.loc[895, 'ilçeler'] = 'Köprübaşı (Trabzon)'
ilçe.loc[955, 'ilçeler'] = 'Kemer (Burdur)'
ilçe.loc[376, 'ilçeler'] = 'Kemer (Antalya)'
ilçe.loc[811, 'ilçeler'] = 'Altınyayla (Sivas)'
ilçe.loc[909, 'ilçeler'] = 'Altınyayla (Burdur)'
ilçe.loc[782, 'ilçeler'] = 'Aydıncık (Yozgat)'
ilçe.loc[767, 'ilçeler'] = 'Aydıncık (Mersin)'
ilçe.loc[445, 'ilçeler'] = 'Ayvacık (Çanakkale)'
ilçe.loc[580, 'ilçeler'] = 'Ayvacık (Samsun)'
ilçe.loc[665, 'ilçeler'] = 'Bayat (Çorum)'
ilçe.loc[852, 'ilçeler'] = 'Bayat (Afyonkarahisar)'
ilçe.loc[796, 'ilçeler'] = 'Bozkurt (Kastamonu)'
ilçe.loc[740, 'ilçeler'] = 'Bozkurt (Denizli)'
ilçe.loc[532, 'ilçeler'] = 'Demre (Antalya)'
ilçe.loc[153, 'ilçeler'] = 'Edremit (Balıkesir)'
ilçe.loc[186, 'ilçeler'] = 'Edremit (Van)'
ilçe.loc[161, 'ilçeler'] = 'Ereğli (Konya)'
ilçe.loc[130, 'ilçeler'] = 'Ereğli (Zonguldak)'
ilçe.loc[45, 'ilçeler'] = 'Eyüp'
ilçe.loc[179, 'ilçeler'] = 'Gölbaşı(Ankara)'
ilçe.loc[340, 'ilçeler'] = 'Gölbaşı (Adıyaman)'
ilçe.loc[266, 'ilçeler'] = 'Gönen (Balıkesir)'
ilçe.loc[859, 'ilçeler'] = 'Gönen (Isparta)'
ilçe.loc[902, 'ilçeler'] = 'Kale (Malatya)'
ilçe.loc[607, 'ilçeler'] = 'Kale (Denizli)'
ilçe.loc[694, 'ilçeler'] = 'Yesilli'
ilçe.loc[581, 'ilçeler'] = 'Sultan Karahisar'
ilçe.loc[413, 'ilçeler'] = 'Suhut'
ilçe.loc[404, 'ilçeler'] = 'Sarkışla'
ilçe.loc[754, 'ilçeler'] = 'Salpazarı'
ilçe.loc[387, 'ilçeler'] = 'Resadiye'
ilçe.loc[526, 'ilçeler'] = 'Ondokuz Mayıs'
ilçe.loc[49, 'ilçeler'] = 'Merkez (Şanlıurfa)'
ilçe.loc[225, 'ilçeler'] = 'Merkez (İzmit)'
ilçe.loc[68, 'ilçeler'] = 'Merkez (Van)'
ilçe.loc[62, 'ilçeler'] = 'Merkez (Samsun)'
ilçe.loc[66, 'ilçeler'] = 'Merkez (Trabzon)'
ilçe.loc[155, 'ilçeler'] = 'Merkez (Tekirdağ)'
ilçe.loc[112, 'ilçeler'] = 'Merkez (Ordu)'
ilçe.loc[211, 'ilçeler'] = 'Merkez (Muğla)'
ilçe.loc[118, 'ilçeler'] = 'Merkez (Mersin)'
ilçe.loc[131, 'ilçeler'] = 'Merkez (Mardin)'
ilçe.loc[101, 'ilçeler'] = 'Merkez (Manisa)'
ilçe.loc[75,'ilçeler'] = 'Merkez (Malatya)'
ilçe.loc[105 , 'ilçeler'] = 'Merkez (Kahramanmaraş)'
ilçe.loc[47, 'ilçeler'] = 'Merkez (Hatay)'
ilçe.loc[42, 'ilçeler'] = 'Merkez (Eskişehir)'
ilçe.loc[121, 'ilçeler'] = 'Merkez (Erzurum)'
ilçe.loc[54, 'ilçeler'] = 'Merkez (Diyarbakır)'
ilçe.loc[555, 'ilçeler'] = 'Askale'
ilçe.loc[936, 'ilçeler'] = 'Aydınlar'
ilçe.loc[792, 'ilçeler'] = 'Basmakçı'
ilçe.loc[195, 'ilçeler'] = 'Doğubeyazıt'
ilçe.loc[430, 'ilçeler'] = 'Esme'
ilçe.loc[298, 'ilçeler'] = 'Ilıca'
ilçe.loc[599, 'ilçeler'] = 'Kesap'
ilçe.loc[843, 'ilçeler'] = 'Kızılırmak'
ilçe.loc[364, 'ilçeler'] = 'Merkez (Adapazarı)'
ilçe.loc[123, 'ilçeler'] = 'Merkez (Antalya)'
ilçe.loc[79, 'ilçeler'] = 'Merkez (Aydın)'
ilçe.loc[124, 'ilçeler'] = 'Merkez (Balıkesir)'
ilçe.loc[58, 'ilçeler'] = 'Merkez (Denizli)'

# %%
ilçe=ilçe.reset_index(drop=True)

# %%
polygons=polygons.reset_index(drop=True)

# %%
#Merging the two datasets in order to match the town names.

# %%
merged = pd.merge(left=polygons,right=ilçe, left_on='name', right_on='ilçeler', how='left')

# %%
merged.loc[13, 'kişibaşına_yol'] = 0
merged.loc[107, 'kişibaşına_yol'] = 0
merged.loc[475, 'kişibaşına_yol'] = 20000/8220
merged.loc[547, 'kişibaşına_yol'] = 76000/153511

# %%
#Using the matplotlib visualization package, below choropleth map is obtained.

# %%
fig, ax = plt.subplots(1, figsize=(20, 10))
merged.plot(column='kişibaşına_yol', scheme='FisherJenks',ax=ax, legend=True, markersize=5, cmap='Paired', k=8)
ax.axis('off')
ax.set_title('Per Capita Divided Roads/Higways in Meters of the Towns in Turkey', fontdict={'fontsize': '15', 'fontweight' : '3'})
ax.annotate('Source: Google Maps API',xy=(0.1, .08),  xycoords='figure fraction', horizontalalignment='left', verticalalignment='top', fontsize=12, color='#555555')
plt.tight_layout()

# %%
fig.savefig("per_capita_roads_TahaEren.png")

# %%
import folium

# %%
gmaps.geocode('Turkey')
# Out:
# [{'address_components': [{'long_name': 'Turkey',
#     'short_name': 'TR',
#     'types': ['country', 'political']}],
#   'formatted_address': 'Turkey',
#   'geometry': {'bounds': {'northeast': {'lat': 42.3666999, 'lng': 44.8178449},
#     'southwest': {'lat': 35.808592, 'lng': 25.5377}},
#    'location': {'lat': 38.963745, 'lng': 35.243322},
#    'location_type': 'APPROXIMATE',
#    'viewport': {'northeast': {'lat': 42.3666999, 'lng': 44.8178449},
#     'southwest': {'lat': 35.808592, 'lng': 25.5377}}},
#   'place_id': 'ChIJcSZPllwVsBQRKl9iKtTb2UA',
#   'types': ['country', 'political']}]

# %%
m = folium.Map(location=[38.963745, 35.243322], zoom_start=6)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
ilçe['feature.properties.name'] = ilçe['ilçeler']
polygons['feature.id'] = polygons['name']

# %%
m.choropleth(
 geo_data='https://raw.githubusercontent.com/tahasarnic/ilceler/master/turkiye-ilceler.geojson',
 name='choropleth',
 data=ilçe,
 columns=['ilçeler', 'kişibaşına_yol'],
 key_on='feature.properties.name',
 fill_color='YlGn',
 legend_name='Road Per Capita (in meters)'
)
folium.LayerControl().add_to(m)

# %%
#interactive map is like below. Since the package requires direct geojson json data. Some names did not match properly as the
#previous choropleth plot.

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m.save('TahaEren_Project.html')
